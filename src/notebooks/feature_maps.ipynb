# %% [markdown]
# # Feature map visualization (toy)
# Load baseline/pruned/retrained models and save activation grids for selected layers.

# %%
from pathlib import Path
import sys, json, torch

repo_root = Path("/mnt/hdd/ttoxopeus/basic_UNet")
if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))

from toy.feature_maps import compare_feature_maps
from toy.datasets import get_synthetic_loaders, ShapesDatasetConfig
from src.models.unet import UNet  # allowlist for torch.load

# ---- configure your run (use a run created after full-model save fix) ----
run_dir = Path("/mnt/hdd/ttoxopeus/basic_UNet/toy/results/multiclass_tinyunet_20260127_141643")  # replace
baseline_ckpt = run_dir / "baseline.pth"           # state_dict
pruned_ckpt   = run_dir / "pruned_model_r0_3.pth"  # full model
retrained_ckpt = run_dir / "retrained_pruned_r0_3.pth"  # optional full model
device = torch.device("cpu")  # force CPU to avoid device mismatches during viz

# load model config from summary
summary = json.load(open(run_dir / "summary.json", "r"))
features = summary["model"]["features"]
out_ch = summary["model"]["out_ch"]
print("features", features, "out_ch", out_ch)
# Out:
# features [2, 4, 8] out_ch 4

# %%
# Debug: inspect checkpoint object types
torch.serialization.add_safe_globals([UNet])
for name, ckpt in [("baseline", baseline_ckpt), ("pruned", pruned_ckpt), ("retrained", retrained_ckpt)]:
    if ckpt.exists():
        obj = torch.load(ckpt, map_location="cpu", weights_only=False)
        print(f"{name} ckpt type: {type(obj)}")
    else:
        print(f"{name} ckpt missing: {ckpt}")
# Out:
# baseline ckpt type: <class 'collections.OrderedDict'>
# pruned ckpt type: <class 'src.models.unet.UNet'>
# retrained ckpt type: <class 'src.models.unet.UNet'>

# %%
# ---- get a sample (synthetic val) ----
cfg = ShapesDatasetConfig(num_samples=200, image_size=64, mode="multiclass", fg_classes=3, seed=42)
val_loader = get_synthetic_loaders(cfg=cfg, batch_size=1, val_ratio=0.2, num_workers=0)[1]
sample_img, _ = next(iter(val_loader))
sample_img = sample_img.to(device)
print("sample_img", sample_img.shape, "device", sample_img.device)
# Out:
# sample_img torch.Size([1, 1, 64, 64])

# %%
# ---- choose layers and export ----
layers = ["encoders.0.net.0", "encoders.1.net.0", "encoders.2.net.0", "bottleneck.net.0"]
out_dir = run_dir / "feature_maps"

print("baseline exists", baseline_ckpt.exists(), "pruned exists", pruned_ckpt.exists(), "retrained exists", retrained_ckpt.exists())
print("device:", device)

compare_feature_maps(
    baseline_ckpt=baseline_ckpt,
    pruned_ckpt=pruned_ckpt,
    retrained_ckpt=retrained_ckpt if retrained_ckpt.exists() else None,
    sample=sample_img,
    layers=layers,
    features=features,
    out_ch=out_ch,
    device=device,
    out_dir=out_dir,
    max_channels=16,
)
print("Saved feature maps to", out_dir)
# Out:
# baseline exists True pruned exists True retrained exists True
# device: cuda
# [DEBUG] sample device before loop: cuda:0, target device: cuda
# [DEBUG] loading baseline from /mnt/hdd/ttoxopeus/basic_UNet/toy/results/multiclass_tinyunet_20260127_141643/baseline.pth (exists: True)
# [DEBUG] baseline model device: cuda:0, sample device: cuda:0
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 8
#       5 print("baseline exists", baseline_ckpt.exists(), "pruned exists", pruned_ckpt.exists(), "retrained exists", retrained_ckpt.exists())
#       6 print("device:", device)
# ----> 8 compare_feature_maps(
#       9     baseline_ckpt=baseline_ckpt,
#      10     pruned_ckpt=pruned_ckpt,
#      11     retrained_ckpt=retrained_ckpt if retrained_ckpt.exists() else None,
#      12     sample=sample_img,
#      13     layers=layers,
#      14     features=features,
#      15     out_ch=out_ch,
#      16     device=device,
#      17     out_dir=out_dir,
#      18     max_channels=16,
#      19 )
#      20 print("Saved feature maps to", out_dir)
#
# File /mnt/hdd/ttoxopeus/basic_UNet/toy/feature_maps.py:93, in compare_feature_maps(baseline_ckpt, pruned_ckpt, retrained_ckpt, sample, layers, features, out_ch, device, out_dir, max_channels)
#      90 sample_device = sample.to(model_dev)
#      91 print(f"[DEBUG] {label} model device: {model_dev}, sample device: {sample_device.device}")
# ---> 93 acts = _capture(model, layers, sample_device)
#      94 print(f"[DEBUG] {label} captured layers: {list(acts.keys())}")
#      95 for lname, act in acts.items():
#
# File /mnt/hdd/ttoxopeus/basic_UNet/toy/feature_maps.py:40, in _capture(model, layers, x)
#      38         hooks.append(module.register_forward_hook(lambda _m, _i, o, n=name: acts.setdefault(n, o.detach().cpu())))
#      39 with torch.no_grad():
# ---> 40     _ = model(x)
#      41 for h in hooks:
#      42     h.remove()
#
# File /media/ttoxopeus/miniconda3/envs/nnunet/lib/python3.10/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File /media/ttoxopeus/miniconda3/envs/nnunet/lib/python3.10/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File /mnt/hdd/ttoxopeus/basic_UNet/src/models/unet.py:104, in UNet.forward(self, x)
#     102 # Encoder path
#     103 for enc in self.encoders:
# --> 104     x = enc(x)
#     105     skip_connections.append(x)
#     106     x = self.pool(x)
#
# File /media/ttoxopeus/miniconda3/envs/nnunet/lib/python3.10/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File /media/ttoxopeus/miniconda3/envs/nnunet/lib/python3.10/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File /mnt/hdd/ttoxopeus/basic_UNet/src/models/unet.py:20, in DoubleConv.forward(self, x)
#      19 def forward(self, x):
# ---> 20     return self.net(x)
#
# File /media/ttoxopeus/miniconda3/envs/nnunet/lib/python3.10/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File /media/ttoxopeus/miniconda3/envs/nnunet/lib/python3.10/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File /media/ttoxopeus/miniconda3/envs/nnunet/lib/python3.10/site-packages/torch/nn/modules/container.py:244, in Sequential.forward(self, input)
#     242 def forward(self, input):
#     243     for module in self:
# --> 244         input = module(input)
#     245     return input
#
# File /media/ttoxopeus/miniconda3/envs/nnunet/lib/python3.10/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File /media/ttoxopeus/miniconda3/envs/nnunet/lib/python3.10/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File /media/ttoxopeus/miniconda3/envs/nnunet/lib/python3.10/site-packages/torch/nn/modules/batchnorm.py:193, in _BatchNorm.forward(self, input)
#     186     bn_training = (self.running_mean is None) and (self.running_var is None)
#     188 r"""
#     189 Buffers are only updated if they are to be tracked and we are in training mode. Thus they only need to be
#     190 passed when the update should occur (i.e. in training mode when they are tracked), or when buffer stats are
#     191 used for normalization (i.e. in eval mode when buffers are not None).
#     192 """
# --> 193 return F.batch_norm(
#     194     input,
#     195     # If buffers are not to be tracked, ensure that they won't be updated
#     196     self.running_mean
#     197     if not self.training or self.track_running_stats
#     198     else None,
#     199     self.running_var if not self.training or self.track_running_stats else None,
#     200     self.weight,
#     201     self.bias,
#     202     bn_training,
#     203     exponential_average_factor,
#     204     self.eps,
#     205 )
#
# File /media/ttoxopeus/miniconda3/envs/nnunet/lib/python3.10/site-packages/torch/nn/functional.py:2817, in batch_norm(input, running_mean, running_var, weight, bias, training, momentum, eps)
#    2814 if training:
#    2815     _verify_batch_size(input.size())
# -> 2817 return torch.batch_norm(
#    2818     input,
#    2819     weight,
#    2820     bias,
#    2821     running_mean,
#    2822     running_var,
#    2823     training,
#    2824     momentum,
#    2825     eps,
#    2826     torch.backends.cudnn.enabled,
#    2827 )
#
# RuntimeError: Expected all tensors to be on the same device, but got weight is on cuda:0, different from other tensors on cpu (when checking argument in method wrapper_CUDA__native_batch_norm)
